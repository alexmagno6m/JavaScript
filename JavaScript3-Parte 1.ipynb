// %% [markdown]
// ### JavaScript<br>Sesión 3 <br> Profesor: Alexander Acevedo<br>Ingenierio de Sistemas<br>Colegio Antonio Baraya

// %% [markdown]
// # Funciones en JavaScript - Parte 1 (introducción)
// Una función es un bloque de código diseñado para realizar una tarea particular. Fuente: [w3schools](https://www.w3schools.com/js/js_functions.asp)
// >## Partes de una Función
// Una función en JavaScipt está compuesta por:![Dise%C3%B1o-sin-t%C3%ADtulo-13.png](attachment:Dise%C3%B1o-sin-t%C3%ADtulo-13.png)
// >
// > En JavaScript una función se define mediante la palabra reservada ___function___, seguida por un ___nombre___ (name), seguida por paréntisis ( ) dentro de los cuales deben escribirse los ___parámetros___ según el caso.
// >> - __Function__: Su uso es obligatorio, la sentencia _function_ es una palabra reservada del lenguaje, sirve para indicarle al interprete que se está definiendo una función.
// >> - __Nombre__: las funciones deben tener asignado un nombre, este no puede ser una palabra reservada del lenguaje y debe cumplir las mismas reglas de las variables (no iniciar con un número, ni tener espacios, pueden tener guiones bajos). En la imagen la función es nombrada con la palabra _"add"_.
// >> - __Parámetros o Argumentos__: Son variables que recibe una función, deben esribirse entre paréntesis y separarse por comas. Son opcionales dependiendo del contexto de la función. La función de la imagen tiene dos parámetros: _a, b_.
// >> - __Cuerpo__: contiene el conjunto de instrucciones que ejecutará la función al momento de ser llamada. El cuerpo debe estar entre llaves { }. Una función debe tener al menos una instrucción en su cuerpo. No puede estar vacía.
// >> - __Retorno__: se espeficifica mediante la sentencia _return_. Las funciones, pueden retornar valores, esto es necesario para poder comprobar su funcionamiento, además el uso de valores de retorno sirve para emplear la función en otras operaciones dentro del código de JavaScript o incluso en otras funciones. La sentencia _return_  debe ser la última línea de código del cuerpo de la función. En la imagen se retorna la suma de _a + b_.
// >
// > Dentro de la función los parámetros y variables se comportarán como variables locales, es decir, no pueden ser usados por fuera de la función.
// > ## Invocación o llamado de una función
// El código dentro de la función sólo se ejecuta cuando "algo" llama a la función. Existen tres maneras comunes de llamar a una función:
// > - Cuando un evento ocurre, por ejemplo, al hacer clic en un botón.
// > - Cuando es invocada (llamada) desde otra parte del código de JavaScript.
// > - Automáticamente (autoinvocada).
// >> Desde el código se invoca la función directamente haciendo uso de la siguiente sentencia:<br>
// >> __nombre_función(argumento1, argumento2, ...);__
// >
// > ## Ejemplo 1
// > Desde la consola, crearemos una función llamada MetrosKilometros, la cual debe recibir como parametro un valor en _metros_ para ser convertidos a _kilometros_ y retornar este valor.
// > Ingrese a la consola con la tecla f12 o haciendo clic en el menú de desarrollador de su navegador.

// %%
function MetrosKilometros(metros){
    kilometros = metros/1000;
    return kilometros;
    }

// %% [markdown]
// > Después de definida la función, procedemos a invocarla, pasando como argumento 20000 metros:

// %%
function MetrosKilometros(metros){
    kilometros = metros/1000;
    return kilometros;
    }
MetrosKilometros(20000);
// Out:
// 20

// %% [markdown]
// >El resultado es 20 kilómetros 👍
// >>Si al llamar a la función obviamos los paréntesis, el código devolverá la definición de la función en lugar del resultado de la función:

// %%
MetrosKilometros;
// Out:
// [Function: MetrosKilometros]

// %% [markdown]
// >## Funciones usadas como valores de variables
// > Muchas veces conviene usar las funciones como valores de variables, esto facilita realizar otras operaciones o cálculos.
// >>Siguiendo con el ejemplo 1, podemos "guardar" el retorno de la funcion MetrosKilometros en la variable x, y luego usar esta variable para por ejemplo mostrar una ventana emergente:

// %%
x=MetrosKilometros(20000);
window.alert("este es el resultado" + x);

// %% [markdown]
// > ## Por qué usar funciones?
// La primera utilidad de las funciones es elemental: permite dividir el código en diferentes secciones lo cual facilita su ejecución y eficiencia. Sin embargo, hay una ventaja más poderosa en el uso de funciones: Sirven para crear elementos interactivos entre el código HTML y el usuario usando como puente a JavaScript. Por ejemplo:
// > - Eventos en botones
// > - Controlar el acceso a otras páginas de nuestro sitio web
// > - Reproducir animaciones
// > - Verificar datos
// > - Formularios interactivos
// > - Usar API's (Application Programming Interface - Interfaz de Programación de Aplicaciones) de terceros, por ejemplo Google Maps, Facebook, Instagram, Gmail, etc.
